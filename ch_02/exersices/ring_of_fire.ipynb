# %%
import pandas as pd

# %%
df_quakes = pd.read_csv("../data/parsed.csv")

# %%
sr_ring_places = pd.Series(name="place",data=[
   "Bolivia",
   "Chile",
   "Ecuador",
   "Peru",
   "Costa Rica",
   "Guatemala",
   "Mexico",
   "Japan",
   "Philippines",
   "Indonesia",
   "New Zealand",
   "Antarctic",
   "Canada",
   "Fiji",
   "Alaska",
   "Washington",
   "California",
   "Russia",
   "Taiwan",
   "Tonga",
   "Kermadec Islands"])

# %%
df_ring = df_quakes[df_quakes.parsed_place.isin(sr_ring_places)]
df_ring.parsed_place.value_counts()
sr_not_found = sr_ring_places[~sr_ring_places.isin(df_ring.parsed_place)]
sr_not_found
# Out:
# 11    Antarctic
# Name: place, dtype: object

# %%
df_antarctic = df_quakes[df_quakes.parsed_place.str.contains("Antarctic")]
df_antarctic
# Out:
#       alert  cdi      code                                             detail  \
# 391     NaN  NaN  1000hb0u  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1895    NaN  NaN  1000h8fm  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1900  green  NaN  1000h8fi  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 7535    NaN  NaN  2000hiw3  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#         dmin  felt    gap           ids  mag magType  ...    status  \
# 391   29.331   NaN  121.0  ,us1000hb0u,  5.1      mb  ...  reviewed
# 1895  28.498   NaN  130.0  ,us1000h8fm,  5.1      mb  ...  reviewed
# 1900  30.792   NaN  105.0  ,us1000h8fi,  5.6     mww  ...  reviewed
# 7535  16.501   NaN  134.0  ,us2000hiw3,  5.1      mb  ...  reviewed
#
#                time                                   title tsunami  \
# 391   1539337221080         M 5.1 - Pacific-Antarctic Ridge       0
# 1895  1538876662920         M 5.1 - Pacific-Antarctic Ridge       0
# ...

# %%
df_ring = pd.concat([df_ring, df_antarctic])
df_ring
# Out:
#       alert  cdi      code                                             detail  \
# 0       NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1       NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2       NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3       NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4       NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
# ...     ...  ...       ...                                                ...
# 7535    NaN  NaN  2000hiw3  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 391     NaN  NaN  1000hb0u  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1895    NaN  NaN  1000h8fm  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1900  green  NaN  1000h8fi  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 7535    NaN  NaN  2000hiw3  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
# ...

# %% [markdown]
# ## Number of quakes in ring: 7188

# %%
len(df_quakes) - len(df_ring)
# Out:
# 2140

# %% [markdown]
# ## Number of quakes not in ring: 2140

# %%
df_ring.tsunami.sum()
# Out:
# 45

# %% [markdown]
# ## Rin tsunami count: 45

# %%
df_quakes.tsunami.sum()
# Out:
# 61
